# %% [markdown]
# Initial Python notebook for Final Course Project on Data Science by IBM

# %%
import pandas as pd
import numpy as np

# %%
print("Hello, final course project!")
# Out:
# Hello, final course project!
